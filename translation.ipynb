# %%
import os
from dotenv import load_dotenv
load_dotenv()
from langchain_core.messages import HumanMessage,SystemMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
grok_api_key=os.getenv('GROQ_API_KEY')

# %%
from langchain_groq import ChatGroq

chat_groq = ChatGroq(model_name="llama-3.1-8b-instant",api_key=grok_api_key)

# %%
languages="Translate the given sentence into {language}:"
prompt = ChatPromptTemplate.from_messages([
    ("system",languages),("user","{text}")
])

# %%
prompt.invoke({"language":"French","text":"My name is kakashi htake"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the given sentence into French:', additional_kwargs={}, response_metadata={}), HumanMessage(content='My name is kakashi htake', additional_kwargs={}, response_metadata={})])

# %%
parser = StrOutputParser()

# %%
chain = prompt|chat_groq|parser

# %%
chain.invoke({"language":"French","text":"My name is kakashi htake"})
# Out:
# 'Here\'s the translation of "My name is Kakashi Hatake" into French:\n\n"Mon nom est Kakashi Hatake."\n\n(Note: In French, the order of the sentence is slightly different, and the verb "est" is used to translate "is".)'
